# %%
import requests
import re
import json
import math
import pandas as pd
import datetime
import requests
import urllib.request
import urllib.error
import urllib.parse
import requests
import itertools
from bs4 import BeautifulSoup
import time
import numpy as np

# %%
data = pd.read_csv("coupang_mask_190411.csv", encoding = 'utf-8', index_col = 0)
data
# Out:
#                                          product_name base_price price_value
# 0                        아이리스 황사마스크 중형 KF80, 100매, 1개        NaN      49,900
# 1                   마쓰미 [장당539원!] 황사마스크KF94, 100매, 1개        NaN      48,000
# 2   김나운의 편안한 황사 미세먼지 차단 마스크/KF94/화이트/5매*20팩총100매, ...        NaN      42,900
# 3                    숨쉬기편한 황사 미세먼지 마스크 KF94 100매, 20개        NaN      15,900
# 4                       프리데이 일회용마스크 블랙 100매 KC인증 3중필터        NaN       6,400
# 5                 하이가드 KF94 황사미세먼지마스크 대형 검정 100매, 10매     20,000       6,800
# 6   마쓰미 [장당 539원] KF94 미세먼지 마쓰미황사마스크 (당일배송 국내제조), ...     59,900      53,900
# 7              듀플렉스 KF94 개별포장 미세먼지마스크 황사마스크, 100매, 1개        NaN      59,800
# 8                            세이브몰 미세먼지 마스크 KF94, 25개입     15,100      14,870
# 9         수성메디칼 하나씩 뽑아쓰는 수성일회용마스크 흰색 100매, 2box, 50매입        NaN       6,600
# 10  황사마스크 타파보카스 KC인증 3중필터 일회용마스크 화이트 100매 황사 미세먼지 ...        NaN       6,700
# ...

# %%
data = pd.read_csv("국세청.csv", encoding = 'euc-kr')
data[:20]
# Out:
#     업태별    시도명  시군구명  성별 (전체)당월① (전체)전월② 증감율(①/②) (전체)전년동월③ 증감율(①/③) (개인)당월①  \
# 0   제조업  서울특별시   종로구  남자   3,941   3,923  100.46%     3,843  102.55%   3,260
# 1   제조업  서울특별시   종로구  여자   1,509   1,510   99.93%     1,434  105.23%   1,307
# 2   제조업  서울특별시   종로구  미상      16      15  106.67%        17   94.12%      13
# 3   제조업  서울특별시    중구  남자   8,988   8,993   99.94%     9,077   99.02%   7,621
# 4   제조업  서울특별시    중구  여자   2,598   2,598  100.00%     2,548  101.96%   2,257
# 5   제조업  서울특별시    중구  미상      15      15  100.00%        14  107.14%      10
# 6   제조업  서울특별시   용산구  남자   1,403   1,393  100.72%     1,395  100.57%     962
# 7   제조업  서울특별시   용산구  여자     583     593   98.31%       549  106.19%     475
# 8   제조업  서울특별시   용산구  미상       5       5  100.00%         6   83.33%       3
# 9   제조업  서울특별시   성동구  남자   4,494   4,491  100.07%     4,530   99.21%   3,198
# 10  제조업  서울특별시   성동구  여자   1,304   1,307   99.77%     1,257  103.74%     991
# ...

# %%
np.unique(data['업태별'])
# Out:
# array(['건설업', '광업', '농·임·어업', '대리,중개,도급업', '도매업', '부동산매매업', '부동산임대업',
#        '서비스업(기타포함)', '소매업', '숙박업', '운수,창고,통신업', '음식업', '전기,가스,수도업', '제조업'],
#       dtype=object)

# %%
data = pd.read_csv("국세청2.csv", encoding = 'euc-kr')
data[:20]
# Out:
#     업태별    시도별  시군구별 (사업자수) 당월① (사업자수)전월② 증감율(①/②) (사업자수)전년동월③ 증감율(①/③)
# 0   가구점  서울특별시   종로구         15        15  100.00%          15  100.00%
# 1   가구점  서울특별시    중구         71        69  102.90%          70  101.43%
# 2   가구점  서울특별시   용산구         36        36  100.00%          41   87.80%
# 3   가구점  서울특별시   성동구         15        13  115.38%          14  107.14%
# 4   가구점  서울특별시   광진구         52        53   98.11%          55   94.55%
# 5   가구점  서울특별시  동대문구         31        31  100.00%          31  100.00%
# 6   가구점  서울특별시   중랑구         28        28  100.00%          32   87.50%
# 7   가구점  서울특별시   성북구         36        36  100.00%          36  100.00%
# 8   가구점  서울특별시   강북구         28        28  100.00%          30   93.33%
# 9   가구점  서울특별시   도봉구         21        21  100.00%          20  105.00%
# 10  가구점  서울특별시   노원구         44        44  100.00%          45   97.78%
# 11  가구점  서울특별시   은평구         39        40   97.50%          41   95.12%
# ...

# %%
np.unique(data['업태별'])
# Out:
# array(['LPG충전소', 'pc방', '가구점', '가전제품수리점', '가전제품판매점', '간이주점', '간판광고물업',
#        '감정평가사', '건강보조식품가게', '건어물가게', '건축사', '결혼상담소', '곡물가게', '공인노무사',
#        '공인회계사', '과일가게', '교습소ㆍ공부방', '교습학원', '구내식당', '기술및직업훈련학원', '기술사',
#        '기타 일반의원', '기타외국식전문점', '기타음식점', '꽃가게', '내과ㆍ소아과 의원', '노래방', '담배가게',
#        '당구장', '독서실', '동물병원', '목욕탕', '문구점', '미용실', '법무사', '변리사', '변호사',
#        '부동산중개업', '분식점', '사진촬영업', '산부인과 의원', '생선가게', '서점', '성형외과 의원',
#        '세무사', '세탁소', '슈퍼마켓', '스포츠교육기관', '스포츠시설운영업', '스포츠용품점', '시계ㆍ귀금속점',
#        '식료품가게', '신경정신과 의원', '신발가게', '실내스크린골프점', '실내장식가게', '실외골프연습장',
#        '안경점', '안과 의원', '애완용품점', '약국', '여관ㆍ모텔', '여행사', '예술학원', '예식장',
#        '옷가게', '의료용품가게', '이륜자동차판매점', '이발소', '이비인후과 의원', '일반외과 의원', '일식전문점',
#        '자동차수리점', '자전거판매점', '장난감가게', '정육점', '제과점', '종합병원', '주유소', '주차장운영업',
#        '중고차판매점', '중식전문점', '채소가게', '철물점', '치과병원ㆍ의원', '침구ㆍ커튼가게', '커피음료점',
#        '컴퓨터판매점', '통신판매업', '패스트푸드점', '펜션ㆍ게스트하우스', '편의점', '피부ㆍ비뇨기과 의원',
# ...
